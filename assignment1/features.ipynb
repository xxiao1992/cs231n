# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None


################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        svm = LinearSVM()
        svm.train(X_train_feats, y_train, learning_rate=lr, reg=reg, 
                  num_iters=1500, verbose=True)
        y_train_pred = svm.predict(X_train_feats)
        y_val_pred = svm.predict(X_val_feats)
        train_acc = np.mean(y_train == y_train_pred)
        val_acc = np.mean(y_val == y_val_pred)
        results[(lr, reg)] = (train_acc, val_acc)
        if best_val < val_acc:
            best_val = val_acc
            best_svm = svm
        print((lr, reg), 'finished')
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 83.783393
# iteration 100 / 1500: loss 83.037889
# iteration 200 / 1500: loss 82.303386
# iteration 300 / 1500: loss 81.571420
# iteration 400 / 1500: loss 80.846127
# iteration 500 / 1500: loss 80.144607
# iteration 600 / 1500: loss 79.414695
# iteration 700 / 1500: loss 78.733016
# iteration 800 / 1500: loss 78.030986
# iteration 900 / 1500: loss 77.360835
# iteration 1000 / 1500: loss 76.678953
# iteration 1100 / 1500: loss 76.008417
# iteration 1200 / 1500: loss 75.321882
# iteration 1300 / 1500: loss 74.672755
# iteration 1400 / 1500: loss 74.018762
# (1e-09, 50000.0) finished
# iteration 0 / 1500: loss 803.036373
# iteration 100 / 1500: loss 727.473459
# iteration 200 / 1500: loss 659.086854
# iteration 300 / 1500: loss 597.207638
# iteration 400 / 1500: loss 541.213821
# iteration 500 / 1500: loss 490.556271
# iteration 600 / 1500: loss 444.717492
# iteration 700 / 1500: loss 403.244019
# iteration 800 / 1500: loss 365.722535
# iteration 900 / 1500: loss 331.756618
# iteration 1000 / 1500: loss 301.044252
# iteration 1100 / 1500: loss 273.241247
# iteration 1200 / 1500: loss 248.091072
# iteration 1300 / 1500: loss 225.337723
# iteration 1400 / 1500: loss 204.743706
# (1e-09, 500000.0) finished
# iteration 0 / 1500: loss 7033.563894
# iteration 100 / 1500: loss 2586.713822
# iteration 200 / 1500: loss 954.907995
# iteration 300 / 1500: loss 356.109130
# iteration 400 / 1500: loss 136.374011
# iteration 500 / 1500: loss 55.740695
# iteration 600 / 1500: loss 26.152288
# iteration 700 / 1500: loss 15.294077
# iteration 800 / 1500: loss 11.309375
# iteration 900 / 1500: loss 9.847418
# iteration 1000 / 1500: loss 9.310956
# iteration 1100 / 1500: loss 9.114068
# iteration 1200 / 1500: loss 9.041864
# iteration 1300 / 1500: loss 9.015347
# iteration 1400 / 1500: loss 9.005628
# (1e-09, 5000000.0) finished
# iteration 0 / 1500: loss 91.300158
# iteration 100 / 1500: loss 83.461841
# iteration 200 / 1500: loss 76.365912
# iteration 300 / 1500: loss 69.949189
# iteration 400 / 1500: loss 64.146264
# iteration 500 / 1500: loss 58.897356
# iteration 600 / 1500: loss 54.158505
# iteration 700 / 1500: loss 49.859175
# iteration 800 / 1500: loss 45.970407
# iteration 900 / 1500: loss 42.453596
# iteration 1000 / 1500: loss 39.269017
# iteration 1100 / 1500: loss 36.382647
# iteration 1200 / 1500: loss 33.770372
# iteration 1300 / 1500: loss 31.417173
# iteration 1400 / 1500: loss 29.292250
# (1e-08, 50000.0) finished
# iteration 0 / 1500: loss 791.497738
# iteration 100 / 1500: loss 296.141577
# iteration 200 / 1500: loss 114.372722
# iteration 300 / 1500: loss 47.669210
# iteration 400 / 1500: loss 23.189314
# iteration 500 / 1500: loss 14.207003
# iteration 600 / 1500: loss 10.910165
# iteration 700 / 1500: loss 9.701418
# iteration 800 / 1500: loss 9.257608
# iteration 900 / 1500: loss 9.094492
# iteration 1000 / 1500: loss 9.034672
# iteration 1100 / 1500: loss 9.012698
# iteration 1200 / 1500: loss 9.004682
# iteration 1300 / 1500: loss 9.001717
# iteration 1400 / 1500: loss 9.000635
# (1e-08, 500000.0) finished
# iteration 0 / 1500: loss 7996.674687
# iteration 100 / 1500: loss 9.280028
# iteration 200 / 1500: loss 9.000010
# iteration 300 / 1500: loss 9.000001
# iteration 400 / 1500: loss 8.999999
# iteration 500 / 1500: loss 9.000000
# iteration 600 / 1500: loss 9.000000
# iteration 700 / 1500: loss 9.000002
# iteration 800 / 1500: loss 8.999999
# iteration 900 / 1500: loss 9.000000
# iteration 1000 / 1500: loss 9.000001
# iteration 1100 / 1500: loss 9.000000
# iteration 1200 / 1500: loss 9.000000
# iteration 1300 / 1500: loss 9.000002
# iteration 1400 / 1500: loss 9.000000
# (1e-08, 5000000.0) finished
# iteration 0 / 1500: loss 87.060046
# iteration 100 / 1500: loss 37.645273
# iteration 200 / 1500: loss 19.513433
# iteration 300 / 1500: loss 12.857747
# iteration 400 / 1500: loss 10.413821
# iteration 500 / 1500: loss 9.519308
# iteration 600 / 1500: loss 9.190224
# iteration 700 / 1500: loss 9.069666
# iteration 800 / 1500: loss 9.025472
# iteration 900 / 1500: loss 9.008982
# iteration 1000 / 1500: loss 9.003488
# iteration 1100 / 1500: loss 9.001285
# iteration 1200 / 1500: loss 9.000397
# iteration 1300 / 1500: loss 9.000246
# iteration 1400 / 1500: loss 9.000158
# (1e-07, 50000.0) finished
# iteration 0 / 1500: loss 788.232852
# iteration 100 / 1500: loss 9.027373
# iteration 200 / 1500: loss 9.000010
# iteration 300 / 1500: loss 9.000008
# iteration 400 / 1500: loss 8.999986
# iteration 500 / 1500: loss 9.000008
# iteration 600 / 1500: loss 8.999999
# iteration 700 / 1500: loss 9.000012
# iteration 800 / 1500: loss 9.000004
# iteration 900 / 1500: loss 9.000013
# iteration 1000 / 1500: loss 9.000012
# iteration 1100 / 1500: loss 9.000016
# iteration 1200 / 1500: loss 9.000005
# iteration 1300 / 1500: loss 8.999999
# iteration 1400 / 1500: loss 9.000002
# (1e-07, 500000.0) finished
# iteration 0 / 1500: loss 7777.259895
# iteration 100 / 1500: loss 9.000003
# iteration 200 / 1500: loss 9.000005
# iteration 300 / 1500: loss 9.000003
# iteration 400 / 1500: loss 9.000002
# iteration 500 / 1500: loss 9.000003
# iteration 600 / 1500: loss 9.000006
# iteration 700 / 1500: loss 9.000004
# iteration 800 / 1500: loss 9.000004
# iteration 900 / 1500: loss 9.000003
# iteration 1000 / 1500: loss 9.000004
# iteration 1100 / 1500: loss 9.000005
# iteration 1200 / 1500: loss 9.000005
# iteration 1300 / 1500: loss 9.000006
# iteration 1400 / 1500: loss 9.000006
# (1e-07, 5000000.0) finished
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.103898 val accuracy: 0.106000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.108020 val accuracy: 0.125000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.119122 val accuracy: 0.102000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.115408 val accuracy: 0.119000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.347857 val accuracy: 0.350000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.417122 val accuracy: 0.420000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.411878 val accuracy: 0.414000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.406245 val accuracy: 0.403000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.392633 val accuracy: 0.389000
# best validation accuracy achieved during cross-validation: 0.420000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.431

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10


best_net = None
best_accu = 0

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
learning_rate = [5e-2, 1e-2, 5e-1]
epochs = [1000, 1500, 2000]
regularization_strength = [1e-3, 5e-3, 1e-2]


for lr in learning_rate:
    for epoch in epochs:
        for reg in regularization_strength:
            # Train the network
            net = TwoLayerNet(input_dim, hidden_dim, num_classes)
            stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                        num_iters=epoch, batch_size=200,
                        learning_rate=lr, learning_rate_decay=0.95,
                        reg=reg, verbose=True)

            param = {'learning_rate': lr,
                     'epoch': epoch,
                     'regularization': reg}
            print(param)
            # Predict on the validation set
            val_acc = (net.predict(X_val_feats) == y_val).mean()
            print('Validation accuracy: ', val_acc)
            if val_acc > best_accu:
                best_net = net
                best_param = param
                best_accu = val_acc
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.303206
# iteration 200 / 1000: loss 2.301590
# iteration 300 / 1000: loss 2.286243
# iteration 400 / 1000: loss 2.132075
# iteration 500 / 1000: loss 1.968902
# iteration 600 / 1000: loss 1.770991
# iteration 700 / 1000: loss 1.759565
# iteration 800 / 1000: loss 1.590629
# iteration 900 / 1000: loss 1.463878
# {'regularization': 0.001, 'learning_rate': 0.05, 'epoch': 1000}
# Validation accuracy:  0.437
# iteration 0 / 1000: loss 2.302589
# iteration 100 / 1000: loss 2.301647
# iteration 200 / 1000: loss 2.301835
# iteration 300 / 1000: loss 2.290138
# iteration 400 / 1000: loss 2.161762
# iteration 500 / 1000: loss 1.978721
# iteration 600 / 1000: loss 1.831702
# iteration 700 / 1000: loss 1.727544
# iteration 800 / 1000: loss 1.706048
# iteration 900 / 1000: loss 1.700596
# {'regularization': 0.005, 'learning_rate': 0.05, 'epoch': 1000}
# Validation accuracy:  0.419
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss 2.303233
# iteration 200 / 1000: loss 2.302280
# iteration 300 / 1000: loss 2.291470
# iteration 400 / 1000: loss 2.210002
# iteration 500 / 1000: loss 2.101908
# iteration 600 / 1000: loss 1.795496
# iteration 700 / 1000: loss 1.832717
# iteration 800 / 1000: loss 1.742158
# iteration 900 / 1000: loss 1.713088
# {'regularization': 0.01, 'learning_rate': 0.05, 'epoch': 1000}
# Validation accuracy:  0.425
# iteration 0 / 1500: loss 2.302586
# iteration 100 / 1500: loss 2.301997
# iteration 200 / 1500: loss 2.300975
# iteration 300 / 1500: loss 2.285925
# iteration 400 / 1500: loss 2.129529
# iteration 500 / 1500: loss 1.891156
# iteration 600 / 1500: loss 1.811579
# iteration 700 / 1500: loss 1.839290
# iteration 800 / 1500: loss 1.606129
# iteration 900 / 1500: loss 1.488817
# iteration 1000 / 1500: loss 1.569891
# iteration 1100 / 1500: loss 1.592502
# iteration 1200 / 1500: loss 1.477813
# iteration 1300 / 1500: loss 1.441102
# iteration 1400 / 1500: loss 1.332274
# {'regularization': 0.001, 'learning_rate': 0.05, 'epoch': 1500}
# Validation accuracy:  0.487
# iteration 0 / 1500: loss 2.302589
# iteration 100 / 1500: loss 2.303245
# iteration 200 / 1500: loss 2.300737
# iteration 300 / 1500: loss 2.292911
# iteration 400 / 1500: loss 2.169681
# iteration 500 / 1500: loss 1.965667
# iteration 600 / 1500: loss 1.824266
# iteration 700 / 1500: loss 1.806861
# iteration 800 / 1500: loss 1.623404
# iteration 900 / 1500: loss 1.750061
# iteration 1000 / 1500: loss 1.612736
# iteration 1100 / 1500: loss 1.519461
# iteration 1200 / 1500: loss 1.584817
# iteration 1300 / 1500: loss 1.424974
# iteration 1400 / 1500: loss 1.444980
# {'regularization': 0.005, 'learning_rate': 0.05, 'epoch': 1500}
# Validation accuracy:  0.489
# iteration 0 / 1500: loss 2.302593
# iteration 100 / 1500: loss 2.302773
# iteration 200 / 1500: loss 2.303580
# iteration 300 / 1500: loss 2.295084
# iteration 400 / 1500: loss 2.215118
# iteration 500 / 1500: loss 2.014193
# iteration 600 / 1500: loss 1.907364
# iteration 700 / 1500: loss 1.846428
# iteration 800 / 1500: loss 1.830075
# iteration 900 / 1500: loss 1.685643
# iteration 1000 / 1500: loss 1.667392
# iteration 1100 / 1500: loss 1.669838
# iteration 1200 / 1500: loss 1.562900
# iteration 1300 / 1500: loss 1.650548
# iteration 1400 / 1500: loss 1.533059
# {'regularization': 0.01, 'learning_rate': 0.05, 'epoch': 1500}
# Validation accuracy:  0.472
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302573
# iteration 200 / 2000: loss 2.301896
# iteration 300 / 2000: loss 2.287719
# iteration 400 / 2000: loss 2.128245
# iteration 500 / 2000: loss 1.908813
# iteration 600 / 2000: loss 1.830875
# iteration 700 / 2000: loss 1.764431
# iteration 800 / 2000: loss 1.630700
# iteration 900 / 2000: loss 1.531949
# iteration 1000 / 2000: loss 1.537785
# iteration 1100 / 2000: loss 1.553177
# iteration 1200 / 2000: loss 1.422230
# iteration 1300 / 2000: loss 1.518921
# iteration 1400 / 2000: loss 1.372637
# iteration 1500 / 2000: loss 1.414405
# iteration 1600 / 2000: loss 1.446844
# iteration 1700 / 2000: loss 1.255405
# iteration 1800 / 2000: loss 1.394627
# iteration 1900 / 2000: loss 1.483175
# {'regularization': 0.001, 'learning_rate': 0.05, 'epoch': 2000}
# Validation accuracy:  0.51
# iteration 0 / 2000: loss 2.302589
# iteration 100 / 2000: loss 2.302181
# iteration 200 / 2000: loss 2.300591
# iteration 300 / 2000: loss 2.292609
# iteration 400 / 2000: loss 2.193878
# iteration 500 / 2000: loss 1.963106
# iteration 600 / 2000: loss 1.746815
# iteration 700 / 2000: loss 1.701657
# iteration 800 / 2000: loss 1.651286
# iteration 900 / 2000: loss 1.636273
# iteration 1000 / 2000: loss 1.605784
# iteration 1100 / 2000: loss 1.579817
# iteration 1200 / 2000: loss 1.530086
# iteration 1300 / 2000: loss 1.468346
# iteration 1400 / 2000: loss 1.530712
# iteration 1500 / 2000: loss 1.445875
# iteration 1600 / 2000: loss 1.472974
# iteration 1700 / 2000: loss 1.404326
# iteration 1800 / 2000: loss 1.507087
# iteration 1900 / 2000: loss 1.494277
# {'regularization': 0.005, 'learning_rate': 0.05, 'epoch': 2000}
# Validation accuracy:  0.492
# iteration 0 / 2000: loss 2.302594
# iteration 100 / 2000: loss 2.301769
# iteration 200 / 2000: loss 2.301640
# iteration 300 / 2000: loss 2.294147
# iteration 400 / 2000: loss 2.196739
# iteration 500 / 2000: loss 2.059086
# iteration 600 / 2000: loss 1.910886
# iteration 700 / 2000: loss 1.901895
# iteration 800 / 2000: loss 1.795001
# iteration 900 / 2000: loss 1.619758
# iteration 1000 / 2000: loss 1.647363
# iteration 1100 / 2000: loss 1.697476
# iteration 1200 / 2000: loss 1.556746
# iteration 1300 / 2000: loss 1.725419
# iteration 1400 / 2000: loss 1.668752
# iteration 1500 / 2000: loss 1.501254
# iteration 1600 / 2000: loss 1.634989
# iteration 1700 / 2000: loss 1.552624
# iteration 1800 / 2000: loss 1.550745
# iteration 1900 / 2000: loss 1.560642
# {'regularization': 0.01, 'learning_rate': 0.05, 'epoch': 2000}
# Validation accuracy:  0.495
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302789
# iteration 200 / 1000: loss 2.302505
# iteration 300 / 1000: loss 2.302568
# iteration 400 / 1000: loss 2.302464
# iteration 500 / 1000: loss 2.302907
# iteration 600 / 1000: loss 2.302360
# iteration 700 / 1000: loss 2.303188
# iteration 800 / 1000: loss 2.302671
# iteration 900 / 1000: loss 2.302518
# {'regularization': 0.001, 'learning_rate': 0.01, 'epoch': 1000}
# Validation accuracy:  0.112
# iteration 0 / 1000: loss 2.302589
# iteration 100 / 1000: loss 2.302715
# iteration 200 / 1000: loss 2.302710
# iteration 300 / 1000: loss 2.302433
# iteration 400 / 1000: loss 2.302748
# iteration 500 / 1000: loss 2.302127
# iteration 600 / 1000: loss 2.302820
# iteration 700 / 1000: loss 2.302643
# iteration 800 / 1000: loss 2.302717
# iteration 900 / 1000: loss 2.302438
# {'regularization': 0.005, 'learning_rate': 0.01, 'epoch': 1000}
# Validation accuracy:  0.079
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 2.302277
# iteration 200 / 1000: loss 2.302825
# iteration 300 / 1000: loss 2.302562
# iteration 400 / 1000: loss 2.302541
# iteration 500 / 1000: loss 2.302279
# iteration 600 / 1000: loss 2.302239
# iteration 700 / 1000: loss 2.302606
# iteration 800 / 1000: loss 2.302491
# iteration 900 / 1000: loss 2.302684
# {'regularization': 0.01, 'learning_rate': 0.01, 'epoch': 1000}
# Validation accuracy:  0.079
# iteration 0 / 1500: loss 2.302586
# iteration 100 / 1500: loss 2.302612
# iteration 200 / 1500: loss 2.302465
# iteration 300 / 1500: loss 2.302792
# iteration 400 / 1500: loss 2.302836
# iteration 500 / 1500: loss 2.302565
# iteration 600 / 1500: loss 2.302562
# iteration 700 / 1500: loss 2.302577
# iteration 800 / 1500: loss 2.302183
# iteration 900 / 1500: loss 2.302683
# iteration 1000 / 1500: loss 2.301787
# iteration 1100 / 1500: loss 2.301947
# iteration 1200 / 1500: loss 2.301179
# iteration 1300 / 1500: loss 2.300573
# iteration 1400 / 1500: loss 2.299408
# {'regularization': 0.001, 'learning_rate': 0.01, 'epoch': 1500}
# Validation accuracy:  0.113
# iteration 0 / 1500: loss 2.302589
# iteration 100 / 1500: loss 2.302641
# iteration 200 / 1500: loss 2.302399
# iteration 300 / 1500: loss 2.302795
# iteration 400 / 1500: loss 2.302506
# iteration 500 / 1500: loss 2.302524
# iteration 600 / 1500: loss 2.302775
# iteration 700 / 1500: loss 2.302354
# iteration 800 / 1500: loss 2.302103
# iteration 900 / 1500: loss 2.302591
# iteration 1000 / 1500: loss 2.302622
# iteration 1100 / 1500: loss 2.301893
# iteration 1200 / 1500: loss 2.301540
# iteration 1300 / 1500: loss 2.301372
# iteration 1400 / 1500: loss 2.299656
# {'regularization': 0.005, 'learning_rate': 0.01, 'epoch': 1500}
# Validation accuracy:  0.208
# iteration 0 / 1500: loss 2.302594
# iteration 100 / 1500: loss 2.302592
# iteration 200 / 1500: loss 2.302692
# iteration 300 / 1500: loss 2.302609
# iteration 400 / 1500: loss 2.302446
# iteration 500 / 1500: loss 2.302476
# iteration 600 / 1500: loss 2.302841
# iteration 700 / 1500: loss 2.302677
# iteration 800 / 1500: loss 2.302793
# iteration 900 / 1500: loss 2.302584
# iteration 1000 / 1500: loss 2.302175
# iteration 1100 / 1500: loss 2.302422
# iteration 1200 / 1500: loss 2.301645
# iteration 1300 / 1500: loss 2.300894
# iteration 1400 / 1500: loss 2.299914
# {'regularization': 0.01, 'learning_rate': 0.01, 'epoch': 1500}
# Validation accuracy:  0.192
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302233
# iteration 200 / 2000: loss 2.303012
# iteration 300 / 2000: loss 2.302299
# iteration 400 / 2000: loss 2.302661
# iteration 500 / 2000: loss 2.302697
# iteration 600 / 2000: loss 2.303027
# iteration 700 / 2000: loss 2.302481
# iteration 800 / 2000: loss 2.302320
# iteration 900 / 2000: loss 2.302825
# iteration 1000 / 2000: loss 2.301729
# iteration 1100 / 2000: loss 2.302083
# iteration 1200 / 2000: loss 2.300831
# iteration 1300 / 2000: loss 2.300874
# iteration 1400 / 2000: loss 2.299554
# iteration 1500 / 2000: loss 2.297190
# iteration 1600 / 2000: loss 2.294601
# iteration 1700 / 2000: loss 2.286871
# iteration 1800 / 2000: loss 2.281390
# iteration 1900 / 2000: loss 2.267953
# {'regularization': 0.001, 'learning_rate': 0.01, 'epoch': 2000}
# Validation accuracy:  0.216
# iteration 0 / 2000: loss 2.302589
# iteration 100 / 2000: loss 2.302750
# iteration 200 / 2000: loss 2.302753
# iteration 300 / 2000: loss 2.302446
# iteration 400 / 2000: loss 2.302567
# iteration 500 / 2000: loss 2.303086
# iteration 600 / 2000: loss 2.302312
# iteration 700 / 2000: loss 2.302675
# iteration 800 / 2000: loss 2.302680
# iteration 900 / 2000: loss 2.302424
# iteration 1000 / 2000: loss 2.302095
# iteration 1100 / 2000: loss 2.302499
# iteration 1200 / 2000: loss 2.301595
# iteration 1300 / 2000: loss 2.301263
# iteration 1400 / 2000: loss 2.299990
# iteration 1500 / 2000: loss 2.298564
# iteration 1600 / 2000: loss 2.296555
# iteration 1700 / 2000: loss 2.290760
# iteration 1800 / 2000: loss 2.290021
# iteration 1900 / 2000: loss 2.273955
# {'regularization': 0.005, 'learning_rate': 0.01, 'epoch': 2000}
# Validation accuracy:  0.203
# iteration 0 / 2000: loss 2.302593
# iteration 100 / 2000: loss 2.302467
# iteration 200 / 2000: loss 2.302538
# iteration 300 / 2000: loss 2.302377
# iteration 400 / 2000: loss 2.302475
# iteration 500 / 2000: loss 2.303088
# iteration 600 / 2000: loss 2.302158
# iteration 700 / 2000: loss 2.302578
# iteration 800 / 2000: loss 2.302925
# iteration 900 / 2000: loss 2.302337
# iteration 1000 / 2000: loss 2.302421
# iteration 1100 / 2000: loss 2.302244
# iteration 1200 / 2000: loss 2.301790
# iteration 1300 / 2000: loss 2.301447
# iteration 1400 / 2000: loss 2.300263
# iteration 1500 / 2000: loss 2.298828
# iteration 1600 / 2000: loss 2.296600
# iteration 1700 / 2000: loss 2.291536
# iteration 1800 / 2000: loss 2.286078
# iteration 1900 / 2000: loss 2.280294
# {'regularization': 0.01, 'learning_rate': 0.01, 'epoch': 2000}
# Validation accuracy:  0.187
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 1.546444
# iteration 200 / 1000: loss 1.419289
# iteration 300 / 1000: loss 1.389690
# iteration 400 / 1000: loss 1.416450
# iteration 500 / 1000: loss 1.310934
# iteration 600 / 1000: loss 1.395543
# iteration 700 / 1000: loss 1.281933
# iteration 800 / 1000: loss 1.290419
# iteration 900 / 1000: loss 1.330014
# {'regularization': 0.001, 'learning_rate': 0.5, 'epoch': 1000}
# Validation accuracy:  0.566
# iteration 0 / 1000: loss 2.302589
# iteration 100 / 1000: loss 1.586476
# iteration 200 / 1000: loss 1.552246
# iteration 300 / 1000: loss 1.513752
# iteration 400 / 1000: loss 1.506920
# iteration 500 / 1000: loss 1.452811
# iteration 600 / 1000: loss 1.535115
# iteration 700 / 1000: loss 1.406281
# iteration 800 / 1000: loss 1.479198
# iteration 900 / 1000: loss 1.426714
# {'regularization': 0.005, 'learning_rate': 0.5, 'epoch': 1000}
# Validation accuracy:  0.546
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss 1.695207
# iteration 200 / 1000: loss 1.521707
# iteration 300 / 1000: loss 1.577130
# iteration 400 / 1000: loss 1.626448
# iteration 500 / 1000: loss 1.615365
# iteration 600 / 1000: loss 1.695483
# iteration 700 / 1000: loss 1.559827
# iteration 800 / 1000: loss 1.547894
# iteration 900 / 1000: loss 1.562988
# {'regularization': 0.01, 'learning_rate': 0.5, 'epoch': 1000}
# Validation accuracy:  0.504
# iteration 0 / 1500: loss 2.302586
# iteration 100 / 1500: loss 1.553254
# iteration 200 / 1500: loss 1.382748
# iteration 300 / 1500: loss 1.356050
# iteration 400 / 1500: loss 1.251733
# iteration 500 / 1500: loss 1.338077
# iteration 600 / 1500: loss 1.297975
# iteration 700 / 1500: loss 1.266105
# iteration 800 / 1500: loss 1.178021
# iteration 900 / 1500: loss 1.258480
# iteration 1000 / 1500: loss 1.267253
# iteration 1100 / 1500: loss 1.183298
# iteration 1200 / 1500: loss 1.159469
# iteration 1300 / 1500: loss 1.115963
# iteration 1400 / 1500: loss 1.162067
# {'regularization': 0.001, 'learning_rate': 0.5, 'epoch': 1500}
# Validation accuracy:  0.579
# iteration 0 / 1500: loss 2.302589
# iteration 100 / 1500: loss 1.641757
# iteration 200 / 1500: loss 1.398587
# iteration 300 / 1500: loss 1.497596
# iteration 400 / 1500: loss 1.536108
# iteration 500 / 1500: loss 1.531194
# iteration 600 / 1500: loss 1.451885
# iteration 700 / 1500: loss 1.489571
# iteration 800 / 1500: loss 1.514409
# iteration 900 / 1500: loss 1.375767
# iteration 1000 / 1500: loss 1.324023
# iteration 1100 / 1500: loss 1.431096
# iteration 1200 / 1500: loss 1.449730
# iteration 1300 / 1500: loss 1.420627
# iteration 1400 / 1500: loss 1.431423
# {'regularization': 0.005, 'learning_rate': 0.5, 'epoch': 1500}
# Validation accuracy:  0.527
# iteration 0 / 1500: loss 2.302593
# iteration 100 / 1500: loss 1.667924
# iteration 200 / 1500: loss 1.597415
# iteration 300 / 1500: loss 1.582876
# iteration 400 / 1500: loss 1.694681
# iteration 500 / 1500: loss 1.606281
# iteration 600 / 1500: loss 1.522857
# iteration 700 / 1500: loss 1.589203
# iteration 800 / 1500: loss 1.605037
# iteration 900 / 1500: loss 1.586502
# iteration 1000 / 1500: loss 1.574026
# iteration 1100 / 1500: loss 1.706968
# iteration 1200 / 1500: loss 1.498241
# iteration 1300 / 1500: loss 1.589246
# iteration 1400 / 1500: loss 1.587396
# {'regularization': 0.01, 'learning_rate': 0.5, 'epoch': 1500}
# Validation accuracy:  0.52
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 1.528282
# iteration 200 / 2000: loss 1.315924
# iteration 300 / 2000: loss 1.484582
# iteration 400 / 2000: loss 1.445602
# iteration 500 / 2000: loss 1.309821
# iteration 600 / 2000: loss 1.123476
# iteration 700 / 2000: loss 1.262356
# iteration 800 / 2000: loss 1.275476
# iteration 900 / 2000: loss 1.265780
# iteration 1000 / 2000: loss 1.092804
# iteration 1100 / 2000: loss 1.286775
# iteration 1200 / 2000: loss 1.209759
# iteration 1300 / 2000: loss 1.161181
# iteration 1400 / 2000: loss 1.172871
# iteration 1500 / 2000: loss 1.150344
# iteration 1600 / 2000: loss 1.160595
# iteration 1700 / 2000: loss 1.240809
# iteration 1800 / 2000: loss 1.109889
# iteration 1900 / 2000: loss 1.127550
# {'regularization': 0.001, 'learning_rate': 0.5, 'epoch': 2000}
# Validation accuracy:  0.615
# iteration 0 / 2000: loss 2.302589
# iteration 100 / 2000: loss 1.507186
# iteration 200 / 2000: loss 1.648187
# iteration 300 / 2000: loss 1.463484
# iteration 400 / 2000: loss 1.507568
# iteration 500 / 2000: loss 1.505782
# iteration 600 / 2000: loss 1.381808
# iteration 700 / 2000: loss 1.492509
# iteration 800 / 2000: loss 1.540684
# iteration 900 / 2000: loss 1.344250
# iteration 1000 / 2000: loss 1.490889
# iteration 1100 / 2000: loss 1.478323
# iteration 1200 / 2000: loss 1.498805
# iteration 1300 / 2000: loss 1.427507
# iteration 1400 / 2000: loss 1.417925
# iteration 1500 / 2000: loss 1.489602
# iteration 1600 / 2000: loss 1.489448
# iteration 1700 / 2000: loss 1.644050
# iteration 1800 / 2000: loss 1.412057
# iteration 1900 / 2000: loss 1.321553
# {'regularization': 0.005, 'learning_rate': 0.5, 'epoch': 2000}
# Validation accuracy:  0.566
# iteration 0 / 2000: loss 2.302594
# iteration 100 / 2000: loss 1.746609
# iteration 200 / 2000: loss 1.563924
# iteration 300 / 2000: loss 1.594890
# iteration 400 / 2000: loss 1.545324
# iteration 500 / 2000: loss 1.663046
# iteration 600 / 2000: loss 1.556893
# iteration 700 / 2000: loss 1.649697
# iteration 800 / 2000: loss 1.617211
# iteration 900 / 2000: loss 1.592125
# iteration 1000 / 2000: loss 1.514459
# iteration 1100 / 2000: loss 1.709536
# iteration 1200 / 2000: loss 1.660749
# iteration 1300 / 2000: loss 1.540365
# iteration 1400 / 2000: loss 1.573710
# iteration 1500 / 2000: loss 1.592462
# iteration 1600 / 2000: loss 1.500736
# iteration 1700 / 2000: loss 1.602237
# iteration 1800 / 2000: loss 1.556590
# iteration 1900 / 2000: loss 1.584998
# {'regularization': 0.01, 'learning_rate': 0.5, 'epoch': 2000}
# Validation accuracy:  0.52

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.585

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
